# %%
import matplotlib.pyplot as plt
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u
cosmo = FlatLambdaCDM(H0=70*u.km/u.s/u.Mpc, Om0=0.3)
import numpy as np
zvals = np.arange(0,6,.1)
lum_dist = cosmo.luminosity_distance(zvals)
fig = plt.figure(figsize = (6,4))
ax = fig.add_subplot(111)
zmin,zmax = 0.0,5.9
ax.plot(zvals,lum_dist)
ax.set_ylabel ("Luminosity Distance (Mpc)")
ax.set_xlabel ("Redshift")
ax.set_xlim(zmin,zmax)
ax.minorticks_on()
ax.set_title ("Luminosity Distance vs Redshift")
# Out:
# Text(0.5, 1.0, 'Luminosity Distance vs Redshift')
